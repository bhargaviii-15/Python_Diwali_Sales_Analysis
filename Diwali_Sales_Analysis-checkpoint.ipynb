# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\HP\Downloads\Python_Diwali_Sales_Analysis-main\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv', encoding = 'unicode_escape')
#to avoid encoding error use 'unicode_escape'

# %%
df.shape
#shape to return number of rows and columns present in the dataset
# Out:
# (11251, 13)

# %%
df.head()
#head returns the first 5 rows in the table (when row numbers are passesd that many rows will be displayed)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.info()
#info is to check the data present in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True) 
#drop function is used to delete unrelated, blank columns etc in the table, 'axis=1' means enetire row 
#and 'inplace=true' means that the made changes need to be saved

# %%
df.info()
#to chcek whether the changes are made
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
#to check whether there are any null values in the datset
#where the data is showed "false" then their is no null value if shown "true" then there are null values
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
#to calculate how many null values are present
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)
#to drop null values

# %%
df.shape
#to check whether the chnages are made
# Out:
# (11239, 13)

# %%
df['Amount'] = df['Amount'].astype('int') 
#to change the datatype

# %%
df['Amount'].dtypes
#to chcek the data type of particular data
# Out:
# dtype('int64')

# %%
df.columns
#to check what columns are there in the dataframe
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.rename(columns= {'Marital _Status': 'Shadhi'})
#to rename the column name "This is just temporary won't be saved coz we have no used inplace=True"
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe()
#describe() runs description method of the data in the datframe (i.e, cont, sum, mean, etc...)
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#use describe() for specific columns
df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # *Exploratory Data Analysis*

# %% [markdown]
# ## *Gender*

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'Gender', data= df)
for bars in ax.containers:
    ax.bar_label(bars)
#plotting graph on the basis of gender count

# %%
df.groupby(['Gender'], as_index= False)['Amount'].sum().sort_values(by='Amount', ascending= False)
#sorting the total salesa done by each gender based on amount in descending order
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
#plot graph for the above
sales_gen= df.groupby(['Gender'], as_index= False)['Amount'].sum().sort_values(by='Amount', ascending= False)
sns.barplot(x= 'Gender', y= 'Amount', data= sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# **From the above Graph we can see that most of the buyers are Female and even the purchasing power of frmales are greater than men**

# %% [markdown]
# ## **Age**

# %%
ax= sns.countplot(x= 'Age Group', data= df, hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)
#hue is used to add legends

# %%
#Total Amount vs Age group
sales_age= df.groupby(['Age Group'], as_index= False)['Amount'].sum().sort_values(by= 'Amount', ascending= False)
sns.barplot(x= 'Age Group', y= 'Amount', data= sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# __**From above graph we can see the most of the buyers are of age group between 26-35yrs female**__

# %% [markdown]
# ## **Sales**

# %%
#Total number of Orders from Top 10 States
sales_state=df.groupby(['State'], as_index= False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x= 'State', y= 'Orders', data= sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
#Total amount of sales based on Top 10 States
#figure.figsize is used to alter grap view
sales_state=df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by= 'Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x= 'State', y= 'Amount', data= sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
#  **From the above graph we can see the most of the orders and sales are from Uttar Pradesh, Maharshtra and Karnataka respectively**

# %% [markdown]
# ## **Marital Status**

# %%
ax= sns.countplot(x= 'Marital_Status', data=df)
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)
#to display marital status

# %%
sales_status=df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by= 'Amount', ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x= 'Marital_Status', y= 'Amount', hue= 'Gender', data= sales_status)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# **From the above graphs we can see most of the buyers are married(women) and they have purchasing power**

# %% [markdown]
# ## **Occupation**

# %%
#to plot bar graph for occupation
sns.set(rc={'figure.figsize':(20,5)})
ax= sns.countplot(x= 'Occupation', data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#to group occupation by sales 
sales_occ= df.groupby(['Occupation'], as_index= False)['Amount'].sum().sort_values(by= 'Amount', ascending= False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x= 'Occupation', y= 'Amount', data= sales_occ)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# **From the above graph we can see most of the buyers work at IT, Healthcare and Aviation**

# %% [markdown]
# ## Product Category

# %%
# to create bar graph for products
sns.set(rc={'figure.figsize':(30,10)})
ax= sns.countplot(x= 'Product_Category', data= df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_pro=df.groupby(['Product_Category'], as_index= False)['Amount'].sum().sort_values(by= 'Amount', ascending= False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x= 'Product_Category', y= 'Amount', data= sales_pro)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# **From the above graph we can see most of sold products are food, clothing and electronic**

# %%
#Top 10 most sold products
sales_pro=df.groupby(['Product_ID'], as_index= False)['Orders'].sum().sort_values(by= 'Orders', ascending= False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x= 'Product_ID', y= 'Orders', data= sales_pro)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Married women age group 26-35 yrs from UP, Maharashtra and Karnataka working at IT, Healthcare and Aviationare more likely to buy products from Food, Clothing and Electronics Category**

# %% [markdown]
# complete project on GitHub: "https://github.com/bhargaviii-15/Python_Diwali_Sales_Analysis"

# %% [markdown]
# **Thank You!**
